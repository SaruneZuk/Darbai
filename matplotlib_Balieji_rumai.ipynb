# %%
import matplotlib.pyplot as plt
# Vyru ir moteru pokytis kiekvienais metais Baltuosiuose rumuose atvaizduotas grafike

informacija = []
with open('wh_staff_dataset.csv') as failas:
    failas.readline()
    for eilute in failas:
        eilute = eilute.strip()
        isskaidyta = eilute.split(',')
        #print(isskaidyta)
        info = dict(
            metai = isskaidyta[0],
            vardas = isskaidyta[1],
            lytis = isskaidyta[2],
            statusas = isskaidyta[3],
            atlyginimas = int(isskaidyta[4])if isskaidyta[4].isdigit() else 0,
            laikotarpis = isskaidyta[5],
            pareigos = isskaidyta[6]
            )
        informacija.append(info)
        #print(info)
moterys_1997 = []
moterys_1998 = []
moterys_1999 = []
moterys_2000 = []
moterys_2001 = []
moterys_2002 = []
moterys_2003 = []
moterys_2004 = []
moterys_2005 = []
moterys_2006 = []
moterys_2007 = []
moterys_2008 = []
moterys_2009 = []
moterys_2010 = []
moterys_2011 = []
moterys_2012 = []
moterys_2013 = []
moterys_2014 = []
moterys_2015 = []
moterys_2016 = []
moterys_2017 = []
moterys_2018 = []
moterys_2019 = []
moterys_2020 = []
vyrai_1997 = []
vyrai_1998 = []
vyrai_1999 = []
vyrai_2000 = []
vyrai_2001 = []
vyrai_2002 = []
vyrai_2003 = []
vyrai_2004 = []
vyrai_2005 = []
vyrai_2006 = []
vyrai_2007 = []
vyrai_2008 = []
vyrai_2009 = []
vyrai_2010 = []
vyrai_2011 = []
vyrai_2012 = []
vyrai_2013 = []
vyrai_2014 = []
vyrai_2015 = []
vyrai_2016 = []
vyrai_2017 = []
vyrai_2018 = []
vyrai_2019 = []
vyrai_2020 = []
for info in informacija:
    if info['lytis'] == 'Female' and info['metai'] == '1997':
        moterys_1997.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '1998':
        moterys_1998.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '1999':
        moterys_1999.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2000':
        moterys_2000.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2001':
        moterys_2001.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2002':
        moterys_2002.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2003':
        moterys_2003.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2004':
        moterys_2004.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2005':
        moterys_2005.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2006':
        moterys_2006.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2007':
        moterys_2007.append(info)        
    elif info['lytis'] == 'Female' and info['metai'] == '2008':
        moterys_2008.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2009':
        moterys_2009.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2010':
        moterys_2010.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2011':
        moterys_2011.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2012':
        moterys_2012.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2013':
        moterys_2013.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2014':
        moterys_2014.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2015':
        moterys_2015.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2016':
        moterys_2016.append(info)        
    elif info['lytis'] == 'Female' and info['metai'] == '2017':
        moterys_2017.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2018':
        moterys_2018.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2019':
        moterys_2019.append(info)
    elif info['lytis'] == 'Female' and info['metai'] == '2020':
        moterys_2020.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '1997':
        vyrai_1997.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '1998':
        vyrai_1998.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '1999':
        vyrai_1999.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2000':
        vyrai_2000.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2001':
        vyrai_2001.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2002':
        vyrai_2002.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2003':
        vyrai_2003.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2004':
        vyrai_2004.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2005':
        vyrai_2005.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2006':
        vyrai_2006.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2007':
        vyrai_2007.append(info)        
    elif info['lytis'] == 'Male' and info['metai'] == '2008':
        vyrai_2008.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2009':
        vyrai_2009.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2010':
        vyrai_2010.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2011':
        vyrai_2011.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2012':
        vyrai_2012.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2013':
        vyrai_2013.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2014':
        vyrai_2014.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2015':
        vyrai_2015.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2016':
        vyrai_2016.append(info)        
    elif info['lytis'] == 'Male' and info['metai'] == '2017':
        vyrai_2017.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2018':
        vyrai_2018.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2019':
        vyrai_2019.append(info)
    elif info['lytis'] == 'Male' and info['metai'] == '2020':
        vyrai_2020.append(info)
sarasas_moteru = list[len(moterys_1997), len(moterys_1998), len(moterys_1999), len(moterys_2000), len(moterys_2001), len(moterys_2002), len(moterys_2003), len(moterys_2004), len(moterys_2005), len(moterys_2006), len(moterys_2007), len(moterys_2008), len(moterys_2009), len(moterys_2010), len(moterys_2011), len(moterys_2012), len(moterys_2013), len(moterys_2014), len(moterys_2015), len(moterys_2016), len(moterys_2017), len(moterys_2018), len(moterys_2019), len(moterys_2020)]
print('Moterų dirbusių 1997 - 2020 sąrašas', sarasas_moteru)
sarasas_vyru = list[len(vyrai_1997), len(vyrai_1998), len(vyrai_1999), len(vyrai_2000), len(vyrai_2001), len(vyrai_2002), len(vyrai_2003), len(vyrai_2004), len(vyrai_2005), len(vyrai_2006), len(vyrai_2007), len(vyrai_2008), len(vyrai_2009), len(vyrai_2010), len(vyrai_2011), len(vyrai_2012), len(vyrai_2013), len(vyrai_2014), len(vyrai_2015), len(vyrai_2016), len(vyrai_2017), len(vyrai_2018), len(vyrai_2019), len(vyrai_2020)]
print('Vyrų dirbusių 1997 - 2020 sąrašas', sarasas_vyru)

Metai = [1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
Moterys = [258, 250, 274, 271, 217, 266, 251, 239, 229, 230, 213, 219, 243, 230, 220, 231, 235, 235, 264, 269, 173, 184, 196, 189]
Vyrai = [154, 155, 153, 155, 164, 222, 201, 169, 156, 186, 210, 205, 229, 222, 220, 224, 213, 209, 197, 186, 189, 175, 208, 212]
plt.plot(Metai,Moterys, label='Moterys',color= 'magenta', marker = '.', markersize = 10, markeredgecolor = 'magenta')
plt.plot(Metai, Vyrai, label='Vyrai',color= 'mediumblue', marker = '.', markersize = 10, markeredgecolor = 'mediumblue')
plt.title('Baltuosiuose Rūmuose 1997-2020  metais \n dirbusių moterų ir vyrų grafikas',fontdict={'color': 'teal','size': 20})
plt.xlabel('Metai')
plt.ylabel('Dirbusiųjų kiekis')
plt.xticks(rotation = 90)
plt.xticks(ticks=[1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020])
plt.yticks(ticks=[150,160,170,180,190,200,210,220,230,240,250,260,270,280])
plt.legend()
plt.show
print('Ižvalga: nuo 2016 iki 2017 metų drąstiškai krito moterų dirbusių Baltuosiuose Rūmuose skaičius. \nTam įtakos galėjo turėti 2016 metais išrinktas naujasis Prezidentas Donald Trump.')
# Out:
# Moterų dirbusių 1997 - 2020 sąrašas list[258, 250, 275, 272, 217, 266, 252, 240, 230, 231, 214, 220, 243, 230, 220, 231, 235, 235, 264, 270, 173, 184, 196, 189]
# Vyrų dirbusių 1997 - 2020 sąrašas list[170, 170, 174, 172, 180, 247, 215, 189, 177, 201, 229, 227, 244, 239, 234, 237, 225, 221, 210, 202, 204, 190, 222, 223]
# Ižvalga: nuo 2016 iki 2017 metų drąstiškai krito moterų dirbusių Baltuosiuose Rūmuose skaičius.
# Tam įtakos galėjo turėti 2016 metais išrinktas naujasis Prezidentas Donald Trump.
